# %%
import os, sys
import django

sys.path.append('../..') # add path to project root dir
os.environ["DJANGO_SETTINGS_MODULE"] = "cancer.settings"
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

from django.core.wsgi import get_wsgi_application
application = get_wsgi_application()
# Out:
# Loading Data Encryption (init)...
#  * loading keys from /Users/kebadiretsemotlhabi/source/cancer-project/cancer/crypto_fields
#  * loading rsa.restricted.public ... Done.
#  * loading rsa.restricted.private ... Done.
#  * loading rsa.local.public ... Done.
#  * loading rsa.local.private ... Done.
#  * loading aes.local ... Done.
#  * loading aes.restricted ... Done.
#  * loading salt.local ... Done.
#  * loading salt.restricted ... Done.
#  Done loading Data Encryption (init)...
# /Users/kebadiretsemotlhabi/.venvs/cancer-eg/lib/python3.10/site-packages/simple_history/models.py:164: UserWarning: HistoricalRecords added to abstract model (HistoryManagerMixin) without inherit=True
#   warnings.warn(msg, UserWarning)
# /Users/kebadiretsemotlhabi/.venvs/cancer-eg/lib/python3.10/site-packages/simple_history/models.py:164: UserWarning: HistoricalRecords added to abstract model (ScheduleModelMixin) without inherit=True
#   warnings.warn(msg, UserWarning)
# ...

# %%
from cancer_subject.models import SubjectVisit

subject_identifier = '045-040996568-5'

# get subject visit where reason is death
subject_visit= SubjectVisit.objects.filter(appointment__subject_identifier=subject_identifier,reason='Death').latest('report_datetime')

subject_visit.delete()
